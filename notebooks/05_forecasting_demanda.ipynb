# %% [markdown]
# # Forecasting de Demanda

# %% [markdown]
# ## Librerías

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from statsmodels.tsa.arima.model import ARIMA
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Generar series temporales sintéticas

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from statsmodels.tsa.arima.model import ARIMA
import warnings
warnings.filterwarnings("ignore")

# Cargar métricas base
df = pd.read_csv("metricas_venta_integradas.csv")

# Crear rango de fechas semanales (52 semanas)
fechas = pd.date_range(start="2024-01-01", periods=52, freq="W")

# Generar dataset sintético
datos_sinteticos = []
for _, row in df.iterrows():
    for fecha in fechas:
        cantidad = max(0, np.random.normal(row["demanda_promedio"], row["desviacion_demanda"]))
        datos_sinteticos.append({
            "fecha": fecha,
            "sku": row["sku"],
            "tienda": row["tienda"],
            "cantidad_vendida": round(cantidad, 2)
        })

ventas_sinteticas = pd.DataFrame(datos_sinteticos)
ventas_sinteticas.to_csv("ventas.csv", index=False)

print("✅ Archivo 'ventas.csv' generado correctamente con", len(ventas_sinteticas), "registros.")
print(ventas_sinteticas.head(10))
# Out:
# ✅ Archivo 'ventas.csv' generado correctamente con 52000 registros.
#        fecha       sku     tienda  cantidad_vendida
# 0 2024-01-07  HM000001  TIENDA001              0.80
# 1 2024-01-14  HM000001  TIENDA001              2.48
# 2 2024-01-21  HM000001  TIENDA001              0.14
# 3 2024-01-28  HM000001  TIENDA001              2.48
# 4 2024-02-04  HM000001  TIENDA001              2.20
# 5 2024-02-11  HM000001  TIENDA001              0.43
# 6 2024-02-18  HM000001  TIENDA001              1.02
# 7 2024-02-25  HM000001  TIENDA001              2.10
# 8 2024-03-03  HM000001  TIENDA001              1.80
# 9 2024-03-10  HM000001  TIENDA001              2.05

# %% [markdown]
# ## Forecasting ARIMA (resultados_forecast.csv)

# %%
# ===============================================================
# Pronóstico de demanda con ARIMA
# ===============================================================
import warnings
warnings.filterwarnings('ignore')

from statsmodels.tsa.arima.model import ARIMA
import pandas as pd

# Leer las ventas sintéticas
df = pd.read_csv("ventas.csv")
df["fecha"] = pd.to_datetime(df["fecha"])

resultados = []

# Generar forecast por SKU-Tienda
for (sku, tienda), grupo in df.groupby(["sku", "tienda"]):
    grupo = grupo.sort_values("fecha")
    y = grupo["cantidad_vendida"].values

    # Validar longitud mínima
    if len(y) < 10 or y.sum() == 0:
        print(f"⏭ Sin datos suficientes para {sku} - {tienda}")
        continue

    try:
        modelo = ARIMA(y, order=(1,1,1))
        modelo_fit = modelo.fit()
        pred = modelo_fit.forecast(steps=8)
        fechas_futuras = pd.date_range(start=grupo["fecha"].iloc[-1], periods=8, freq="W")

        for i, f in enumerate(fechas_futuras):
            resultados.append({
                "sku": sku,
                "tienda": tienda,
                "fecha_predicha": f,
                "semana_a_futuro": i+1,
                "prediccion_ARIMA": round(float(pred[i]), 2)
            })
        print(f" Predicción generada para {sku} - {tienda}")
    except Exception as e:
        print(f" Error en {sku}-{tienda}: {e}")

# Guardar resultados
df_forecast = pd.DataFrame(resultados)
df_forecast.to_csv("resultados_forecast.csv", index=False)
print("\n Archivo 'resultados_forecast.csv' generado correctamente.")
print("Filas:", len(df_forecast))
print(df_forecast.head(10))
# Out:
# ✅ Predicción generada para HM000001 - TIENDA001
# ✅ Predicción generada para HM000001 - TIENDA002
# ✅ Predicción generada para HM000001 - TIENDA002
# ✅ Predicción generada para HM000001 - TIENDA003
# ✅ Predicción generada para HM000001 - TIENDA003
# ✅ Predicción generada para HM000001 - TIENDA004
# ✅ Predicción generada para HM000001 - TIENDA004
# ✅ Predicción generada para HM000001 - TIENDA005
# ✅ Predicción generada para HM000001 - TIENDA005
# ✅ Predicción generada para HM000001 - TIENDA006
# ✅ Predicción generada para HM000001 - TIENDA006
# ✅ Predicción generada para HM000001 - TIENDA007
# ✅ Predicción generada para HM000001 - TIENDA007
# ✅ Predicción generada para HM000001 - TIENDA008
# ✅ Predicción generada para HM000001 - TIENDA008
# ✅ Predicción generada para HM000001 - TIENDA009
# ✅ Predicción generada para HM000001 - TIENDA009
# ✅ Predicción generada para HM000001 - TIENDA010
# ✅ Predicción generada para HM000001 - TIENDA010
# ✅ Predicción generada para HM000002 - TIENDA001
# ✅ Predicción generada para HM000002 - TIENDA001
# ✅ Predicción generada para HM000002 - TIENDA002
# ✅ Predicción generada para HM000002 - TIENDA002
# ✅ Predicción generada para HM000002 - TIENDA003
# ✅ Predicción generada para HM000002 - TIENDA003
# ✅ Predicción generada para HM000002 - TIENDA004
# ✅ Predicción generada para HM000002 - TIENDA004
# ✅ Predicción generada para HM000002 - TIENDA005
# ✅ Predicción generada para HM000002 - TIENDA005
# ✅ Predicción generada para HM000002 - TIENDA006
# ✅ Predicción generada para HM000002 - TIENDA006
# ✅ Predicción generada para HM000002 - TIENDA007
# ✅ Predicción generada para HM000002 - TIENDA007
# ✅ Predicción generada para HM000002 - TIENDA008
# ✅ Predicción generada para HM000002 - TIENDA008
# ✅ Predicción generada para HM000002 - TIENDA009
# ✅ Predicción generada para HM000002 - TIENDA009
# ✅ Predicción generada para HM000002 - TIENDA010
# ✅ Predicción generada para HM000002 - TIENDA010
# ✅ Predicción generada para HM000003 - TIENDA001
# ✅ Predicción generada para HM000003 - TIENDA001
# ✅ Predicción generada para HM000003 - TIENDA002
# ✅ Predicción generada para HM000003 - TIENDA002
# ✅ Predicción generada para HM000003 - TIENDA003
# ✅ Predicción generada para HM000003 - TIENDA003
# ✅ Predicción generada para HM000003 - TIENDA004
# ✅ Predicción generada para HM000003 - TIENDA004
# ✅ Predicción generada para HM000003 - TIENDA005
# ✅ Predicción generada para HM000003 - TIENDA005
# ✅ Predicción generada para HM000003 - TIENDA006
# ✅ Predicción generada para HM000003 - TIENDA006
# ✅ Predicción generada para HM000003 - TIENDA007
# ✅ Predicción generada para HM000003 - TIENDA007
# ✅ Predicción generada para HM000003 - TIENDA008
# ✅ Predicción generada para HM000003 - TIENDA008
# ✅ Predicción generada para HM000003 - TIENDA009
# ✅ Predicción generada para HM000003 - TIENDA009
# ✅ Predicción generada para HM000003 - TIENDA010
# ✅ Predicción generada para HM000003 - TIENDA010
# ✅ Predicción generada para HM000004 - TIENDA001
# ✅ Predicción generada para HM000004 - TIENDA001
# ✅ Predicción generada para HM000004 - TIENDA002
# ✅ Predicción generada para HM000004 - TIENDA002
# ✅ Predicción generada para HM000004 - TIENDA003
# ✅ Predicción generada para HM000004 - TIENDA003
# ✅ Predicción generada para HM000004 - TIENDA004
# ✅ Predicción generada para HM000004 - TIENDA004
# ✅ Predicción generada para HM000004 - TIENDA005
# ✅ Predicción generada para HM000004 - TIENDA005
# ✅ Predicción generada para HM000004 - TIENDA006
# ✅ Predicción generada para HM000004 - TIENDA006
# ✅ Predicción generada para HM000004 - TIENDA007
# ✅ Predicción generada para HM000004 - TIENDA007
# ✅ Predicción generada para HM000004 - TIENDA008
# ✅ Predicción generada para HM000004 - TIENDA008
# ✅ Predicción generada para HM000004 - TIENDA009
# ✅ Predicción generada para HM000004 - TIENDA009
# ✅ Predicción generada para HM000004 - TIENDA010
# ✅ Predicción generada para HM000004 - TIENDA010
# ✅ Predicción generada para HM000005 - TIENDA001
# ✅ Predicción generada para HM000005 - TIENDA001
# ✅ Predicción generada para HM000005 - TIENDA002
# ✅ Predicción generada para HM000005 - TIENDA002
# ✅ Predicción generada para HM000005 - TIENDA003
# ✅ Predicción generada para HM000005 - TIENDA003
# ✅ Predicción generada para HM000005 - TIENDA004
# ✅ Predicción generada para HM000005 - TIENDA004
# ✅ Predicción generada para HM000005 - TIENDA005
# ✅ Predicción generada para HM000005 - TIENDA005
# ✅ Predicción generada para HM000005 - TIENDA006
# ✅ Predicción generada para HM000005 - TIENDA006
# ✅ Predicción generada para HM000005 - TIENDA007
# ✅ Predicción generada para HM000005 - TIENDA007
# ✅ Predicción generada para HM000005 - TIENDA008
# ✅ Predicción generada para HM000005 - TIENDA008
# ✅ Predicción generada para HM000005 - TIENDA009
# ✅ Predicción generada para HM000005 - TIENDA009
# ✅ Predicción generada para HM000005 - TIENDA010
# ✅ Predicción generada para HM000005 - TIENDA010
# ✅ Predicción generada para HM000006 - TIENDA001
# ✅ Predicción generada para HM000006 - TIENDA001
# ✅ Predicción generada para HM000006 - TIENDA002
# ✅ Predicción generada para HM000006 - TIENDA002
# ✅ Predicción generada para HM000006 - TIENDA003
# ✅ Predicción generada para HM000006 - TIENDA003
# ✅ Predicción generada para HM000006 - TIENDA004
# ✅ Predicción generada para HM000006 - TIENDA004
# ✅ Predicción generada para HM000006 - TIENDA005
# ✅ Predicción generada para HM000006 - TIENDA005
# ✅ Predicción generada para HM000006 - TIENDA006
# ✅ Predicción generada para HM000006 - TIENDA006
# ✅ Predicción generada para HM000006 - TIENDA007
# ✅ Predicción generada para HM000006 - TIENDA007
# ✅ Predicción generada para HM000006 - TIENDA008
# ✅ Predicción generada para HM000006 - TIENDA008
# ✅ Predicción generada para HM000006 - TIENDA009
# ✅ Predicción generada para HM000006 - TIENDA009
# ✅ Predicción generada para HM000006 - TIENDA010
# ✅ Predicción generada para HM000006 - TIENDA010
# ✅ Predicción generada para HM000007 - TIENDA001
# ✅ Predicción generada para HM000007 - TIENDA001
# ✅ Predicción generada para HM000007 - TIENDA002
# ✅ Predicción generada para HM000007 - TIENDA002
# ✅ Predicción generada para HM000007 - TIENDA003
# ✅ Predicción generada para HM000007 - TIENDA003
# ✅ Predicción generada para HM000007 - TIENDA004
# ✅ Predicción generada para HM000007 - TIENDA004
# ✅ Predicción generada para HM000007 - TIENDA005
# ✅ Predicción generada para HM000007 - TIENDA005
# ✅ Predicción generada para HM000007 - TIENDA006
# ✅ Predicción generada para HM000007 - TIENDA006
# ✅ Predicción generada para HM000007 - TIENDA007
# ✅ Predicción generada para HM000007 - TIENDA007
# ✅ Predicción generada para HM000007 - TIENDA008
# ✅ Predicción generada para HM000007 - TIENDA008
# ✅ Predicción generada para HM000007 - TIENDA009
# ✅ Predicción generada para HM000007 - TIENDA009
# ✅ Predicción generada para HM000007 - TIENDA010
# ✅ Predicción generada para HM000007 - TIENDA010
# ✅ Predicción generada para HM000008 - TIENDA001
# ✅ Predicción generada para HM000008 - TIENDA001
# ✅ Predicción generada para HM000008 - TIENDA002
# ✅ Predicción generada para HM000008 - TIENDA002
# ✅ Predicción generada para HM000008 - TIENDA003
# ✅ Predicción generada para HM000008 - TIENDA003
# ✅ Predicción generada para HM000008 - TIENDA004
# ✅ Predicción generada para HM000008 - TIENDA004
# ✅ Predicción generada para HM000008 - TIENDA005
# ✅ Predicción generada para HM000008 - TIENDA005
# ✅ Predicción generada para HM000008 - TIENDA006
# ✅ Predicción generada para HM000008 - TIENDA006
# ✅ Predicción generada para HM000008 - TIENDA007
# ✅ Predicción generada para HM000008 - TIENDA007
# ✅ Predicción generada para HM000008 - TIENDA008
# ✅ Predicción generada para HM000008 - TIENDA008
# ✅ Predicción generada para HM000008 - TIENDA009
# ✅ Predicción generada para HM000008 - TIENDA009
# ✅ Predicción generada para HM000008 - TIENDA010
# ✅ Predicción generada para HM000008 - TIENDA010
# ✅ Predicción generada para HM000009 - TIENDA001
# ✅ Predicción generada para HM000009 - TIENDA001
# ✅ Predicción generada para HM000009 - TIENDA002
# ✅ Predicción generada para HM000009 - TIENDA002
# ✅ Predicción generada para HM000009 - TIENDA003
# ✅ Predicción generada para HM000009 - TIENDA003
# ✅ Predicción generada para HM000009 - TIENDA004
# ✅ Predicción generada para HM000009 - TIENDA004
# ✅ Predicción generada para HM000009 - TIENDA005
# ✅ Predicción generada para HM000009 - TIENDA005
# ✅ Predicción generada para HM000009 - TIENDA006
# ✅ Predicción generada para HM000009 - TIENDA006
# ✅ Predicción generada para HM000009 - TIENDA007
# ✅ Predicción generada para HM000009 - TIENDA007
# ✅ Predicción generada para HM000009 - TIENDA008
# ✅ Predicción generada para HM000009 - TIENDA008
# ✅ Predicción generada para HM000009 - TIENDA009
# ✅ Predicción generada para HM000009 - TIENDA009
# ✅ Predicción generada para HM000009 - TIENDA010
# ✅ Predicción generada para HM000009 - TIENDA010
# ✅ Predicción generada para HM000010 - TIENDA001
# ✅ Predicción generada para HM000010 - TIENDA001
# ✅ Predicción generada para HM000010 - TIENDA002
# ✅ Predicción generada para HM000010 - TIENDA002
# ✅ Predicción generada para HM000010 - TIENDA003
# ✅ Predicción generada para HM000010 - TIENDA003
# ✅ Predicción generada para HM000010 - TIENDA004
# ✅ Predicción generada para HM000010 - TIENDA004
# ✅ Predicción generada para HM000010 - TIENDA005
# ✅ Predicción generada para HM000010 - TIENDA005
# ✅ Predicción generada para HM000010 - TIENDA006
# ✅ Predicción generada para HM000010 - TIENDA006
# ✅ Predicción generada para HM000010 - TIENDA007
# ✅ Predicción generada para HM000010 - TIENDA007
# ✅ Predicción generada para HM000010 - TIENDA008
# ✅ Predicción generada para HM000010 - TIENDA008
# ✅ Predicción generada para HM000010 - TIENDA009
# ✅ Predicción generada para HM000010 - TIENDA009
# ✅ Predicción generada para HM000010 - TIENDA010
# ✅ Predicción generada para HM000010 - TIENDA010
# ✅ Predicción generada para HM000011 - TIENDA001
# ✅ Predicción generada para HM000011 - TIENDA001
# ✅ Predicción generada para HM000011 - TIENDA002
# ✅ Predicción generada para HM000011 - TIENDA002
# ✅ Predicción generada para HM000011 - TIENDA003
# ✅ Predicción generada para HM000011 - TIENDA003
# ✅ Predicción generada para HM000011 - TIENDA004
# ✅ Predicción generada para HM000011 - TIENDA004
# ✅ Predicción generada para HM000011 - TIENDA005
# ✅ Predicción generada para HM000011 - TIENDA005
# ✅ Predicción generada para HM000011 - TIENDA006
# ✅ Predicción generada para HM000011 - TIENDA006
# ✅ Predicción generada para HM000011 - TIENDA007
# ✅ Predicción generada para HM000011 - TIENDA007
# ✅ Predicción generada para HM000011 - TIENDA008
# ✅ Predicción generada para HM000011 - TIENDA008
# ✅ Predicción generada para HM000011 - TIENDA009
# ✅ Predicción generada para HM000011 - TIENDA009
# ✅ Predicción generada para HM000011 - TIENDA010
# ✅ Predicción generada para HM000011 - TIENDA010
# ✅ Predicción generada para HM000012 - TIENDA001
# ✅ Predicción generada para HM000012 - TIENDA001
# ✅ Predicción generada para HM000012 - TIENDA002
# ✅ Predicción generada para HM000012 - TIENDA002
# ✅ Predicción generada para HM000012 - TIENDA003
# ✅ Predicción generada para HM000012 - TIENDA003
# ✅ Predicción generada para HM000012 - TIENDA004
# ✅ Predicción generada para HM000012 - TIENDA004
# ✅ Predicción generada para HM000012 - TIENDA005
# ✅ Predicción generada para HM000012 - TIENDA005
# ✅ Predicción generada para HM000012 - TIENDA006
# ✅ Predicción generada para HM000012 - TIENDA006
# ✅ Predicción generada para HM000012 - TIENDA007
# ✅ Predicción generada para HM000012 - TIENDA007
# ✅ Predicción generada para HM000012 - TIENDA008
# ✅ Predicción generada para HM000012 - TIENDA008
# ✅ Predicción generada para HM000012 - TIENDA009
# ✅ Predicción generada para HM000012 - TIENDA009
# ✅ Predicción generada para HM000012 - TIENDA010
# ✅ Predicción generada para HM000012 - TIENDA010
# ✅ Predicción generada para HM000013 - TIENDA001
# ✅ Predicción generada para HM000013 - TIENDA001
# ✅ Predicción generada para HM000013 - TIENDA002
# ✅ Predicción generada para HM000013 - TIENDA002
# ✅ Predicción generada para HM000013 - TIENDA003
# ✅ Predicción generada para HM000013 - TIENDA003
# ✅ Predicción generada para HM000013 - TIENDA004
# ✅ Predicción generada para HM000013 - TIENDA004
# ✅ Predicción generada para HM000013 - TIENDA005
# ✅ Predicción generada para HM000013 - TIENDA005
# ✅ Predicción generada para HM000013 - TIENDA006
# ✅ Predicción generada para HM000013 - TIENDA006
# ✅ Predicción generada para HM000013 - TIENDA007
# ✅ Predicción generada para HM000013 - TIENDA007
# ✅ Predicción generada para HM000013 - TIENDA008
# ✅ Predicción generada para HM000013 - TIENDA008
# ✅ Predicción generada para HM000013 - TIENDA009
# ✅ Predicción generada para HM000013 - TIENDA009
# ✅ Predicción generada para HM000013 - TIENDA010
# ✅ Predicción generada para HM000013 - TIENDA010
# ✅ Predicción generada para HM000014 - TIENDA001
# ✅ Predicción generada para HM000014 - TIENDA001
# ✅ Predicción generada para HM000014 - TIENDA002
# ✅ Predicción generada para HM000014 - TIENDA002
# ✅ Predicción generada para HM000014 - TIENDA003
# ✅ Predicción generada para HM000014 - TIENDA003
# ✅ Predicción generada para HM000014 - TIENDA004
# ✅ Predicción generada para HM000014 - TIENDA004
# ✅ Predicción generada para HM000014 - TIENDA005
# ✅ Predicción generada para HM000014 - TIENDA005
# ✅ Predicción generada para HM000014 - TIENDA006
# ✅ Predicción generada para HM000014 - TIENDA006
# ✅ Predicción generada para HM000014 - TIENDA007
# ✅ Predicción generada para HM000014 - TIENDA007
# ✅ Predicción generada para HM000014 - TIENDA008
# ✅ Predicción generada para HM000014 - TIENDA008
# ✅ Predicción generada para HM000014 - TIENDA009
# ✅ Predicción generada para HM000014 - TIENDA009
# ✅ Predicción generada para HM000014 - TIENDA010
# ✅ Predicción generada para HM000014 - TIENDA010
# ✅ Predicción generada para HM000015 - TIENDA001
# ✅ Predicción generada para HM000015 - TIENDA001
# ✅ Predicción generada para HM000015 - TIENDA002
# ✅ Predicción generada para HM000015 - TIENDA002
# ✅ Predicción generada para HM000015 - TIENDA003
# ✅ Predicción generada para HM000015 - TIENDA003
# ✅ Predicción generada para HM000015 - TIENDA004
# ✅ Predicción generada para HM000015 - TIENDA004
# ✅ Predicción generada para HM000015 - TIENDA005
# ✅ Predicción generada para HM000015 - TIENDA005
# ✅ Predicción generada para HM000015 - TIENDA006
# ✅ Predicción generada para HM000015 - TIENDA006
# ✅ Predicción generada para HM000015 - TIENDA007
# ✅ Predicción generada para HM000015 - TIENDA007
# ✅ Predicción generada para HM000015 - TIENDA008
# ✅ Predicción generada para HM000015 - TIENDA008
# ✅ Predicción generada para HM000015 - TIENDA009
# ✅ Predicción generada para HM000015 - TIENDA009
# ✅ Predicción generada para HM000015 - TIENDA010
# ✅ Predicción generada para HM000015 - TIENDA010
# ✅ Predicción generada para HM000016 - TIENDA001
# ✅ Predicción generada para HM000016 - TIENDA001
# ✅ Predicción generada para HM000016 - TIENDA002
# ✅ Predicción generada para HM000016 - TIENDA002
# ✅ Predicción generada para HM000016 - TIENDA003
# ✅ Predicción generada para HM000016 - TIENDA003
# ✅ Predicción generada para HM000016 - TIENDA004
# ✅ Predicción generada para HM000016 - TIENDA004
# ✅ Predicción generada para HM000016 - TIENDA005
# ✅ Predicción generada para HM000016 - TIENDA005
# ✅ Predicción generada para HM000016 - TIENDA006
# ✅ Predicción generada para HM000016 - TIENDA006
# ✅ Predicción generada para HM000016 - TIENDA007
# ✅ Predicción generada para HM000016 - TIENDA007
# ✅ Predicción generada para HM000016 - TIENDA008
# ✅ Predicción generada para HM000016 - TIENDA008
# ✅ Predicción generada para HM000016 - TIENDA009
# ✅ Predicción generada para HM000016 - TIENDA009
# ✅ Predicción generada para HM000016 - TIENDA010
# ✅ Predicción generada para HM000016 - TIENDA010
# ✅ Predicción generada para HM000017 - TIENDA001
# ✅ Predicción generada para HM000017 - TIENDA001
# ✅ Predicción generada para HM000017 - TIENDA002
# ✅ Predicción generada para HM000017 - TIENDA002
# ✅ Predicción generada para HM000017 - TIENDA003
# ✅ Predicción generada para HM000017 - TIENDA003
# ✅ Predicción generada para HM000017 - TIENDA004
# ✅ Predicción generada para HM000017 - TIENDA004
# ✅ Predicción generada para HM000017 - TIENDA005
# ✅ Predicción generada para HM000017 - TIENDA005
# ✅ Predicción generada para HM000017 - TIENDA006
# ✅ Predicción generada para HM000017 - TIENDA006
# ✅ Predicción generada para HM000017 - TIENDA007
# ✅ Predicción generada para HM000017 - TIENDA007
# ✅ Predicción generada para HM000017 - TIENDA008
# ✅ Predicción generada para HM000017 - TIENDA008
# ✅ Predicción generada para HM000017 - TIENDA009
# ✅ Predicción generada para HM000017 - TIENDA009
# ✅ Predicción generada para HM000017 - TIENDA010
# ✅ Predicción generada para HM000017 - TIENDA010
# ✅ Predicción generada para HM000018 - TIENDA001
# ✅ Predicción generada para HM000018 - TIENDA001
# ✅ Predicción generada para HM000018 - TIENDA002
# ✅ Predicción generada para HM000018 - TIENDA002
# ✅ Predicción generada para HM000018 - TIENDA003
# ✅ Predicción generada para HM000018 - TIENDA003
# ✅ Predicción generada para HM000018 - TIENDA004
# ✅ Predicción generada para HM000018 - TIENDA004
# ✅ Predicción generada para HM000018 - TIENDA005
# ✅ Predicción generada para HM000018 - TIENDA005
# ✅ Predicción generada para HM000018 - TIENDA006
# ✅ Predicción generada para HM000018 - TIENDA006
# ✅ Predicción generada para HM000018 - TIENDA007
# ✅ Predicción generada para HM000018 - TIENDA007
# ✅ Predicción generada para HM000018 - TIENDA008
# ✅ Predicción generada para HM000018 - TIENDA008
# ✅ Predicción generada para HM000018 - TIENDA009
# ✅ Predicción generada para HM000018 - TIENDA009
# ✅ Predicción generada para HM000018 - TIENDA010
# ✅ Predicción generada para HM000018 - TIENDA010
# ✅ Predicción generada para HM000019 - TIENDA001
# ✅ Predicción generada para HM000019 - TIENDA001
# ✅ Predicción generada para HM000019 - TIENDA002
# ✅ Predicción generada para HM000019 - TIENDA002
# ✅ Predicción generada para HM000019 - TIENDA003
# ✅ Predicción generada para HM000019 - TIENDA003
# ✅ Predicción generada para HM000019 - TIENDA004
# ✅ Predicción generada para HM000019 - TIENDA004
# ✅ Predicción generada para HM000019 - TIENDA005
# ✅ Predicción generada para HM000019 - TIENDA005
# ✅ Predicción generada para HM000019 - TIENDA006
# ✅ Predicción generada para HM000019 - TIENDA006
# ✅ Predicción generada para HM000019 - TIENDA007
# ✅ Predicción generada para HM000019 - TIENDA007
# ✅ Predicción generada para HM000019 - TIENDA008
# ✅ Predicción generada para HM000019 - TIENDA008
# ✅ Predicción generada para HM000019 - TIENDA009
# ✅ Predicción generada para HM000019 - TIENDA009
# ✅ Predicción generada para HM000019 - TIENDA010
# ✅ Predicción generada para HM000019 - TIENDA010
# ✅ Predicción generada para HM000020 - TIENDA001
# ✅ Predicción generada para HM000020 - TIENDA001
# ✅ Predicción generada para HM000020 - TIENDA002
# ✅ Predicción generada para HM000020 - TIENDA002
# ✅ Predicción generada para HM000020 - TIENDA003
# ✅ Predicción generada para HM000020 - TIENDA003
# ✅ Predicción generada para HM000020 - TIENDA004
# ✅ Predicción generada para HM000020 - TIENDA004
# ✅ Predicción generada para HM000020 - TIENDA005
# ✅ Predicción generada para HM000020 - TIENDA005
# ✅ Predicción generada para HM000020 - TIENDA006
# ✅ Predicción generada para HM000020 - TIENDA006
# ✅ Predicción generada para HM000020 - TIENDA007
# ✅ Predicción generada para HM000020 - TIENDA007
# ✅ Predicción generada para HM000020 - TIENDA008
# ✅ Predicción generada para HM000020 - TIENDA008
# ✅ Predicción generada para HM000020 - TIENDA009
# ✅ Predicción generada para HM000020 - TIENDA009
# ✅ Predicción generada para HM000020 - TIENDA010
# ✅ Predicción generada para HM000020 - TIENDA010
# ✅ Predicción generada para HM000021 - TIENDA001
# ✅ Predicción generada para HM000021 - TIENDA001
# ✅ Predicción generada para HM000021 - TIENDA002
# ✅ Predicción generada para HM000021 - TIENDA002
# ✅ Predicción generada para HM000021 - TIENDA003
# ✅ Predicción generada para HM000021 - TIENDA003
# ✅ Predicción generada para HM000021 - TIENDA004
# ✅ Predicción generada para HM000021 - TIENDA004
# ✅ Predicción generada para HM000021 - TIENDA005
# ✅ Predicción generada para HM000021 - TIENDA005
# ✅ Predicción generada para HM000021 - TIENDA006
# ✅ Predicción generada para HM000021 - TIENDA006
# ✅ Predicción generada para HM000021 - TIENDA007
# ✅ Predicción generada para HM000021 - TIENDA007
# ✅ Predicción generada para HM000021 - TIENDA008
# ✅ Predicción generada para HM000021 - TIENDA008
# ✅ Predicción generada para HM000021 - TIENDA009
# ✅ Predicción generada para HM000021 - TIENDA009
# ✅ Predicción generada para HM000021 - TIENDA010
# ✅ Predicción generada para HM000021 - TIENDA010
# ✅ Predicción generada para HM000022 - TIENDA001
# ✅ Predicción generada para HM000022 - TIENDA001
# ✅ Predicción generada para HM000022 - TIENDA002
# ✅ Predicción generada para HM000022 - TIENDA002
# ✅ Predicción generada para HM000022 - TIENDA003
# ✅ Predicción generada para HM000022 - TIENDA003
# ✅ Predicción generada para HM000022 - TIENDA004
# ✅ Predicción generada para HM000022 - TIENDA004
# ✅ Predicción generada para HM000022 - TIENDA005
# ✅ Predicción generada para HM000022 - TIENDA005
# ✅ Predicción generada para HM000022 - TIENDA006
# ✅ Predicción generada para HM000022 - TIENDA006
# ✅ Predicción generada para HM000022 - TIENDA007
# ✅ Predicción generada para HM000022 - TIENDA007
# ✅ Predicción generada para HM000022 - TIENDA008
# ✅ Predicción generada para HM000022 - TIENDA008
# ✅ Predicción generada para HM000022 - TIENDA009
# ✅ Predicción generada para HM000022 - TIENDA009
# ✅ Predicción generada para HM000022 - TIENDA010
# ✅ Predicción generada para HM000022 - TIENDA010
# ✅ Predicción generada para HM000023 - TIENDA001
# ✅ Predicción generada para HM000023 - TIENDA001
# ✅ Predicción generada para HM000023 - TIENDA002
# ✅ Predicción generada para HM000023 - TIENDA002
# ✅ Predicción generada para HM000023 - TIENDA003
# ✅ Predicción generada para HM000023 - TIENDA003
# ✅ Predicción generada para HM000023 - TIENDA004
# ✅ Predicción generada para HM000023 - TIENDA004
# ✅ Predicción generada para HM000023 - TIENDA005
# ✅ Predicción generada para HM000023 - TIENDA005
# ✅ Predicción generada para HM000023 - TIENDA006
# ✅ Predicción generada para HM000023 - TIENDA006
# ✅ Predicción generada para HM000023 - TIENDA007
# ✅ Predicción generada para HM000023 - TIENDA007
# ✅ Predicción generada para HM000023 - TIENDA008
# ✅ Predicción generada para HM000023 - TIENDA008
# ✅ Predicción generada para HM000023 - TIENDA009
# ✅ Predicción generada para HM000023 - TIENDA009
# ✅ Predicción generada para HM000023 - TIENDA010
# ✅ Predicción generada para HM000023 - TIENDA010
# ✅ Predicción generada para HM000024 - TIENDA001
# ✅ Predicción generada para HM000024 - TIENDA001
# ✅ Predicción generada para HM000024 - TIENDA002
# ✅ Predicción generada para HM000024 - TIENDA002
# ✅ Predicción generada para HM000024 - TIENDA003
# ✅ Predicción generada para HM000024 - TIENDA003
# ✅ Predicción generada para HM000024 - TIENDA004
# ✅ Predicción generada para HM000024 - TIENDA004
# ✅ Predicción generada para HM000024 - TIENDA005
# ✅ Predicción generada para HM000024 - TIENDA005
# ✅ Predicción generada para HM000024 - TIENDA006
# ✅ Predicción generada para HM000024 - TIENDA006
# ✅ Predicción generada para HM000024 - TIENDA007
# ✅ Predicción generada para HM000024 - TIENDA007
# ✅ Predicción generada para HM000024 - TIENDA008
# ✅ Predicción generada para HM000024 - TIENDA008
# ✅ Predicción generada para HM000024 - TIENDA009
# ✅ Predicción generada para HM000024 - TIENDA009
# ✅ Predicción generada para HM000024 - TIENDA010
# ✅ Predicción generada para HM000024 - TIENDA010
# ✅ Predicción generada para HM000025 - TIENDA001
# ✅ Predicción generada para HM000025 - TIENDA001
# ✅ Predicción generada para HM000025 - TIENDA002
# ✅ Predicción generada para HM000025 - TIENDA002
# ✅ Predicción generada para HM000025 - TIENDA003
# ✅ Predicción generada para HM000025 - TIENDA003
# ✅ Predicción generada para HM000025 - TIENDA004
# ✅ Predicción generada para HM000025 - TIENDA004
# ✅ Predicción generada para HM000025 - TIENDA005
# ✅ Predicción generada para HM000025 - TIENDA005
# ✅ Predicción generada para HM000025 - TIENDA006
# ✅ Predicción generada para HM000025 - TIENDA006
# ✅ Predicción generada para HM000025 - TIENDA007
# ✅ Predicción generada para HM000025 - TIENDA007
# ✅ Predicción generada para HM000025 - TIENDA008
# ✅ Predicción generada para HM000025 - TIENDA008
# ✅ Predicción generada para HM000025 - TIENDA009
# ✅ Predicción generada para HM000025 - TIENDA009
# ✅ Predicción generada para HM000025 - TIENDA010
# ✅ Predicción generada para HM000025 - TIENDA010
# ✅ Predicción generada para HM000026 - TIENDA001
# ✅ Predicción generada para HM000026 - TIENDA001
# ✅ Predicción generada para HM000026 - TIENDA002
# ✅ Predicción generada para HM000026 - TIENDA002
# ✅ Predicción generada para HM000026 - TIENDA003
# ✅ Predicción generada para HM000026 - TIENDA003
# ✅ Predicción generada para HM000026 - TIENDA004
# ✅ Predicción generada para HM000026 - TIENDA004
# ✅ Predicción generada para HM000026 - TIENDA005
# ✅ Predicción generada para HM000026 - TIENDA005
# ✅ Predicción generada para HM000026 - TIENDA006
# ✅ Predicción generada para HM000026 - TIENDA006
# ✅ Predicción generada para HM000026 - TIENDA007
# ✅ Predicción generada para HM000026 - TIENDA007
# ✅ Predicción generada para HM000026 - TIENDA008
# ✅ Predicción generada para HM000026 - TIENDA008
# ✅ Predicción generada para HM000026 - TIENDA009
# ✅ Predicción generada para HM000026 - TIENDA009
# ✅ Predicción generada para HM000026 - TIENDA010
# ✅ Predicción generada para HM000026 - TIENDA010
# ✅ Predicción generada para HM000027 - TIENDA001
# ✅ Predicción generada para HM000027 - TIENDA001
# ✅ Predicción generada para HM000027 - TIENDA002
# ✅ Predicción generada para HM000027 - TIENDA002
# ✅ Predicción generada para HM000027 - TIENDA003
# ✅ Predicción generada para HM000027 - TIENDA003
# ✅ Predicción generada para HM000027 - TIENDA004
# ✅ Predicción generada para HM000027 - TIENDA004
# ✅ Predicción generada para HM000027 - TIENDA005
# ✅ Predicción generada para HM000027 - TIENDA005
# ✅ Predicción generada para HM000027 - TIENDA006
# ✅ Predicción generada para HM000027 - TIENDA006
# ✅ Predicción generada para HM000027 - TIENDA007
# ✅ Predicción generada para HM000027 - TIENDA007
# ✅ Predicción generada para HM000027 - TIENDA008
# ✅ Predicción generada para HM000027 - TIENDA008
# ✅ Predicción generada para HM000027 - TIENDA009
# ✅ Predicción generada para HM000027 - TIENDA009
# ✅ Predicción generada para HM000027 - TIENDA010
# ✅ Predicción generada para HM000027 - TIENDA010
# ✅ Predicción generada para HM000028 - TIENDA001
# ✅ Predicción generada para HM000028 - TIENDA001
# ✅ Predicción generada para HM000028 - TIENDA002
# ✅ Predicción generada para HM000028 - TIENDA002
# ✅ Predicción generada para HM000028 - TIENDA003
# ✅ Predicción generada para HM000028 - TIENDA003
# ✅ Predicción generada para HM000028 - TIENDA004
# ✅ Predicción generada para HM000028 - TIENDA004
# ✅ Predicción generada para HM000028 - TIENDA005
# ✅ Predicción generada para HM000028 - TIENDA005
# ✅ Predicción generada para HM000028 - TIENDA006
# ✅ Predicción generada para HM000028 - TIENDA006
# ✅ Predicción generada para HM000028 - TIENDA007
# ✅ Predicción generada para HM000028 - TIENDA007
# ✅ Predicción generada para HM000028 - TIENDA008
# ✅ Predicción generada para HM000028 - TIENDA008
# ✅ Predicción generada para HM000028 - TIENDA009
# ✅ Predicción generada para HM000028 - TIENDA009
# ✅ Predicción generada para HM000028 - TIENDA010
# ✅ Predicción generada para HM000028 - TIENDA010
# ✅ Predicción generada para HM000029 - TIENDA001
# ✅ Predicción generada para HM000029 - TIENDA001
# ✅ Predicción generada para HM000029 - TIENDA002
# ✅ Predicción generada para HM000029 - TIENDA002
# ✅ Predicción generada para HM000029 - TIENDA003
# ✅ Predicción generada para HM000029 - TIENDA003
# ✅ Predicción generada para HM000029 - TIENDA004
# ✅ Predicción generada para HM000029 - TIENDA004
# ✅ Predicción generada para HM000029 - TIENDA005
# ✅ Predicción generada para HM000029 - TIENDA005
# ✅ Predicción generada para HM000029 - TIENDA006
# ✅ Predicción generada para HM000029 - TIENDA006
# ✅ Predicción generada para HM000029 - TIENDA007
# ✅ Predicción generada para HM000029 - TIENDA007
# ✅ Predicción generada para HM000029 - TIENDA008
# ✅ Predicción generada para HM000029 - TIENDA008
# ✅ Predicción generada para HM000029 - TIENDA009
# ✅ Predicción generada para HM000029 - TIENDA009
# ✅ Predicción generada para HM000029 - TIENDA010
# ✅ Predicción generada para HM000029 - TIENDA010
# ✅ Predicción generada para HM000030 - TIENDA001
# ✅ Predicción generada para HM000030 - TIENDA001
# ✅ Predicción generada para HM000030 - TIENDA002
# ✅ Predicción generada para HM000030 - TIENDA002
# ✅ Predicción generada para HM000030 - TIENDA003
# ✅ Predicción generada para HM000030 - TIENDA003
# ✅ Predicción generada para HM000030 - TIENDA004
# ✅ Predicción generada para HM000030 - TIENDA004
# ✅ Predicción generada para HM000030 - TIENDA005
# ✅ Predicción generada para HM000030 - TIENDA005
# ✅ Predicción generada para HM000030 - TIENDA006
# ✅ Predicción generada para HM000030 - TIENDA006
# ✅ Predicción generada para HM000030 - TIENDA007
# ✅ Predicción generada para HM000030 - TIENDA007
# ✅ Predicción generada para HM000030 - TIENDA008
# ✅ Predicción generada para HM000030 - TIENDA008
# ✅ Predicción generada para HM000030 - TIENDA009
# ✅ Predicción generada para HM000030 - TIENDA009
# ✅ Predicción generada para HM000030 - TIENDA010
# ✅ Predicción generada para HM000030 - TIENDA010
# ✅ Predicción generada para HM000031 - TIENDA001
# ✅ Predicción generada para HM000031 - TIENDA001
# ✅ Predicción generada para HM000031 - TIENDA002
# ✅ Predicción generada para HM000031 - TIENDA002
# ✅ Predicción generada para HM000031 - TIENDA003
# ✅ Predicción generada para HM000031 - TIENDA003
# ✅ Predicción generada para HM000031 - TIENDA004
# ✅ Predicción generada para HM000031 - TIENDA004
# ✅ Predicción generada para HM000031 - TIENDA005
# ✅ Predicción generada para HM000031 - TIENDA005
# ✅ Predicción generada para HM000031 - TIENDA006
# ✅ Predicción generada para HM000031 - TIENDA006
# ✅ Predicción generada para HM000031 - TIENDA007
# ✅ Predicción generada para HM000031 - TIENDA007
# ✅ Predicción generada para HM000031 - TIENDA008
# ✅ Predicción generada para HM000031 - TIENDA008
# ✅ Predicción generada para HM000031 - TIENDA009
# ✅ Predicción generada para HM000031 - TIENDA009
# ✅ Predicción generada para HM000031 - TIENDA010
# ✅ Predicción generada para HM000031 - TIENDA010
# ✅ Predicción generada para HM000032 - TIENDA001
# ✅ Predicción generada para HM000032 - TIENDA001
# ✅ Predicción generada para HM000032 - TIENDA002
# ✅ Predicción generada para HM000032 - TIENDA002
# ✅ Predicción generada para HM000032 - TIENDA003
# ✅ Predicción generada para HM000032 - TIENDA003
# ✅ Predicción generada para HM000032 - TIENDA004
# ✅ Predicción generada para HM000032 - TIENDA004
# ✅ Predicción generada para HM000032 - TIENDA005
# ✅ Predicción generada para HM000032 - TIENDA005
# ✅ Predicción generada para HM000032 - TIENDA006
# ✅ Predicción generada para HM000032 - TIENDA006
# ✅ Predicción generada para HM000032 - TIENDA007
# ✅ Predicción generada para HM000032 - TIENDA007
# ✅ Predicción generada para HM000032 - TIENDA008
# ✅ Predicción generada para HM000032 - TIENDA008
# ✅ Predicción generada para HM000032 - TIENDA009
# ✅ Predicción generada para HM000032 - TIENDA009
# ✅ Predicción generada para HM000032 - TIENDA010
# ✅ Predicción generada para HM000032 - TIENDA010
# ✅ Predicción generada para HM000033 - TIENDA001
# ✅ Predicción generada para HM000033 - TIENDA001
# ✅ Predicción generada para HM000033 - TIENDA002
# ✅ Predicción generada para HM000033 - TIENDA002
# ✅ Predicción generada para HM000033 - TIENDA003
# ✅ Predicción generada para HM000033 - TIENDA003
# ✅ Predicción generada para HM000033 - TIENDA004
# ✅ Predicción generada para HM000033 - TIENDA004
# ✅ Predicción generada para HM000033 - TIENDA005
# ✅ Predicción generada para HM000033 - TIENDA005
# ✅ Predicción generada para HM000033 - TIENDA006
# ✅ Predicción generada para HM000033 - TIENDA006
# ✅ Predicción generada para HM000033 - TIENDA007
# ✅ Predicción generada para HM000033 - TIENDA007
# ✅ Predicción generada para HM000033 - TIENDA008
# ✅ Predicción generada para HM000033 - TIENDA008
# ✅ Predicción generada para HM000033 - TIENDA009
# ✅ Predicción generada para HM000033 - TIENDA009
# ✅ Predicción generada para HM000033 - TIENDA010
# ✅ Predicción generada para HM000033 - TIENDA010
# ✅ Predicción generada para HM000034 - TIENDA001
# ✅ Predicción generada para HM000034 - TIENDA001
# ✅ Predicción generada para HM000034 - TIENDA002
# ✅ Predicción generada para HM000034 - TIENDA002
# ✅ Predicción generada para HM000034 - TIENDA003
# ✅ Predicción generada para HM000034 - TIENDA003
# ✅ Predicción generada para HM000034 - TIENDA004
# ✅ Predicción generada para HM000034 - TIENDA004
# ✅ Predicción generada para HM000034 - TIENDA005
# ✅ Predicción generada para HM000034 - TIENDA005
# ✅ Predicción generada para HM000034 - TIENDA006
# ✅ Predicción generada para HM000034 - TIENDA006
# ✅ Predicción generada para HM000034 - TIENDA007
# ✅ Predicción generada para HM000034 - TIENDA007
# ✅ Predicción generada para HM000034 - TIENDA008
# ✅ Predicción generada para HM000034 - TIENDA008
# ✅ Predicción generada para HM000034 - TIENDA009
# ✅ Predicción generada para HM000034 - TIENDA009
# ✅ Predicción generada para HM000034 - TIENDA010
# ✅ Predicción generada para HM000034 - TIENDA010
# ✅ Predicción generada para HM000035 - TIENDA001
# ✅ Predicción generada para HM000035 - TIENDA001
# ✅ Predicción generada para HM000035 - TIENDA002
# ✅ Predicción generada para HM000035 - TIENDA002
# ✅ Predicción generada para HM000035 - TIENDA003
# ✅ Predicción generada para HM000035 - TIENDA003
# ✅ Predicción generada para HM000035 - TIENDA004
# ✅ Predicción generada para HM000035 - TIENDA004
# ✅ Predicción generada para HM000035 - TIENDA005
# ✅ Predicción generada para HM000035 - TIENDA005
# ✅ Predicción generada para HM000035 - TIENDA006
# ✅ Predicción generada para HM000035 - TIENDA006
# ✅ Predicción generada para HM000035 - TIENDA007
# ✅ Predicción generada para HM000035 - TIENDA007
# ✅ Predicción generada para HM000035 - TIENDA008
# ✅ Predicción generada para HM000035 - TIENDA008
# ✅ Predicción generada para HM000035 - TIENDA009
# ✅ Predicción generada para HM000035 - TIENDA009
# ✅ Predicción generada para HM000035 - TIENDA010
# ✅ Predicción generada para HM000035 - TIENDA010
# ✅ Predicción generada para HM000036 - TIENDA001
# ✅ Predicción generada para HM000036 - TIENDA001
# ✅ Predicción generada para HM000036 - TIENDA002
# ✅ Predicción generada para HM000036 - TIENDA002
# ✅ Predicción generada para HM000036 - TIENDA003
# ✅ Predicción generada para HM000036 - TIENDA003
# ✅ Predicción generada para HM000036 - TIENDA004
# ✅ Predicción generada para HM000036 - TIENDA004
# ✅ Predicción generada para HM000036 - TIENDA005
# ✅ Predicción generada para HM000036 - TIENDA005
# ✅ Predicción generada para HM000036 - TIENDA006
# ✅ Predicción generada para HM000036 - TIENDA006
# ✅ Predicción generada para HM000036 - TIENDA007
# ✅ Predicción generada para HM000036 - TIENDA007
# ✅ Predicción generada para HM000036 - TIENDA008
# ✅ Predicción generada para HM000036 - TIENDA008
# ✅ Predicción generada para HM000036 - TIENDA009
# ✅ Predicción generada para HM000036 - TIENDA009
# ✅ Predicción generada para HM000036 - TIENDA010
# ✅ Predicción generada para HM000036 - TIENDA010
# ✅ Predicción generada para HM000037 - TIENDA001
# ✅ Predicción generada para HM000037 - TIENDA001
# ✅ Predicción generada para HM000037 - TIENDA002
# ✅ Predicción generada para HM000037 - TIENDA002
# ✅ Predicción generada para HM000037 - TIENDA003
# ✅ Predicción generada para HM000037 - TIENDA003
# ✅ Predicción generada para HM000037 - TIENDA004
# ✅ Predicción generada para HM000037 - TIENDA004
# ✅ Predicción generada para HM000037 - TIENDA005
# ✅ Predicción generada para HM000037 - TIENDA005
# ✅ Predicción generada para HM000037 - TIENDA006
# ✅ Predicción generada para HM000037 - TIENDA006
# ✅ Predicción generada para HM000037 - TIENDA007
# ✅ Predicción generada para HM000037 - TIENDA007
# ✅ Predicción generada para HM000037 - TIENDA008
# ✅ Predicción generada para HM000037 - TIENDA008
# ✅ Predicción generada para HM000037 - TIENDA009
# ✅ Predicción generada para HM000037 - TIENDA009
# ✅ Predicción generada para HM000037 - TIENDA010
# ✅ Predicción generada para HM000037 - TIENDA010
# ✅ Predicción generada para HM000038 - TIENDA001
# ✅ Predicción generada para HM000038 - TIENDA001
# ✅ Predicción generada para HM000038 - TIENDA002
# ✅ Predicción generada para HM000038 - TIENDA002
# ✅ Predicción generada para HM000038 - TIENDA003
# ✅ Predicción generada para HM000038 - TIENDA003
# ✅ Predicción generada para HM000038 - TIENDA004
# ✅ Predicción generada para HM000038 - TIENDA004
# ✅ Predicción generada para HM000038 - TIENDA005
# ✅ Predicción generada para HM000038 - TIENDA005
# ✅ Predicción generada para HM000038 - TIENDA006
# ✅ Predicción generada para HM000038 - TIENDA006
# ✅ Predicción generada para HM000038 - TIENDA007
# ✅ Predicción generada para HM000038 - TIENDA007
# ✅ Predicción generada para HM000038 - TIENDA008
# ✅ Predicción generada para HM000038 - TIENDA008
# ✅ Predicción generada para HM000038 - TIENDA009
# ✅ Predicción generada para HM000038 - TIENDA009
# ✅ Predicción generada para HM000038 - TIENDA010
# ✅ Predicción generada para HM000038 - TIENDA010
# ✅ Predicción generada para HM000039 - TIENDA001
# ✅ Predicción generada para HM000039 - TIENDA001
# ✅ Predicción generada para HM000039 - TIENDA002
# ✅ Predicción generada para HM000039 - TIENDA002
# ✅ Predicción generada para HM000039 - TIENDA003
# ✅ Predicción generada para HM000039 - TIENDA003
# ✅ Predicción generada para HM000039 - TIENDA004
# ✅ Predicción generada para HM000039 - TIENDA005
# ✅ Predicción generada para HM000039 - TIENDA006
# ✅ Predicción generada para HM000039 - TIENDA007
# ✅ Predicción generada para HM000039 - TIENDA008
# ✅ Predicción generada para HM000039 - TIENDA009
# ✅ Predicción generada para HM000039 - TIENDA010
# ✅ Predicción generada para HM000040 - TIENDA001
# ✅ Predicción generada para HM000039 - TIENDA004
# ✅ Predicción generada para HM000039 - TIENDA005
# ✅ Predicción generada para HM000039 - TIENDA006
# ✅ Predicción generada para HM000039 - TIENDA007
# ✅ Predicción generada para HM000039 - TIENDA008
# ✅ Predicción generada para HM000039 - TIENDA009
# ✅ Predicción generada para HM000039 - TIENDA010
# ✅ Predicción generada para HM000040 - TIENDA001
# ✅ Predicción generada para HM000040 - TIENDA002
# ✅ Predicción generada para HM000040 - TIENDA002
# ✅ Predicción generada para HM000040 - TIENDA003
# ✅ Predicción generada para HM000040 - TIENDA003
# ✅ Predicción generada para HM000040 - TIENDA004
# ✅ Predicción generada para HM000040 - TIENDA004
# ✅ Predicción generada para HM000040 - TIENDA005
# ✅ Predicción generada para HM000040 - TIENDA005
# ✅ Predicción generada para HM000040 - TIENDA006
# ✅ Predicción generada para HM000040 - TIENDA006
# ✅ Predicción generada para HM000040 - TIENDA007
# ✅ Predicción generada para HM000040 - TIENDA007
# ✅ Predicción generada para HM000040 - TIENDA008
# ✅ Predicción generada para HM000040 - TIENDA008
# ✅ Predicción generada para HM000040 - TIENDA009
# ✅ Predicción generada para HM000040 - TIENDA009
# ✅ Predicción generada para HM000040 - TIENDA010
# ✅ Predicción generada para HM000040 - TIENDA010
# ✅ Predicción generada para HM000041 - TIENDA001
# ✅ Predicción generada para HM000041 - TIENDA001
# ✅ Predicción generada para HM000041 - TIENDA002
# ✅ Predicción generada para HM000041 - TIENDA002
# ✅ Predicción generada para HM000041 - TIENDA003
# ✅ Predicción generada para HM000041 - TIENDA003
# ✅ Predicción generada para HM000041 - TIENDA004
# ✅ Predicción generada para HM000041 - TIENDA004
# ✅ Predicción generada para HM000041 - TIENDA005
# ✅ Predicción generada para HM000041 - TIENDA005
# ✅ Predicción generada para HM000041 - TIENDA006
# ✅ Predicción generada para HM000041 - TIENDA006
# ✅ Predicción generada para HM000041 - TIENDA007
# ✅ Predicción generada para HM000041 - TIENDA007
# ✅ Predicción generada para HM000041 - TIENDA008
# ✅ Predicción generada para HM000041 - TIENDA008
# ✅ Predicción generada para HM000041 - TIENDA009
# ✅ Predicción generada para HM000041 - TIENDA009
# ✅ Predicción generada para HM000041 - TIENDA010
# ✅ Predicción generada para HM000041 - TIENDA010
# ✅ Predicción generada para HM000042 - TIENDA001
# ✅ Predicción generada para HM000042 - TIENDA001
# ✅ Predicción generada para HM000042 - TIENDA002
# ✅ Predicción generada para HM000042 - TIENDA002
# ✅ Predicción generada para HM000042 - TIENDA003
# ✅ Predicción generada para HM000042 - TIENDA003
# ✅ Predicción generada para HM000042 - TIENDA004
# ✅ Predicción generada para HM000042 - TIENDA004
# ✅ Predicción generada para HM000042 - TIENDA005
# ✅ Predicción generada para HM000042 - TIENDA005
# ✅ Predicción generada para HM000042 - TIENDA006
# ✅ Predicción generada para HM000042 - TIENDA006
# ✅ Predicción generada para HM000042 - TIENDA007
# ✅ Predicción generada para HM000042 - TIENDA007
# ✅ Predicción generada para HM000042 - TIENDA008
# ✅ Predicción generada para HM000042 - TIENDA008
# ✅ Predicción generada para HM000042 - TIENDA009
# ✅ Predicción generada para HM000042 - TIENDA009
# ✅ Predicción generada para HM000042 - TIENDA010
# ✅ Predicción generada para HM000042 - TIENDA010
# ✅ Predicción generada para HM000043 - TIENDA001
# ✅ Predicción generada para HM000043 - TIENDA001
# ✅ Predicción generada para HM000043 - TIENDA002
# ✅ Predicción generada para HM000043 - TIENDA002
# ✅ Predicción generada para HM000043 - TIENDA003
# ✅ Predicción generada para HM000043 - TIENDA003
# ✅ Predicción generada para HM000043 - TIENDA004
# ✅ Predicción generada para HM000043 - TIENDA004
# ✅ Predicción generada para HM000043 - TIENDA005
# ✅ Predicción generada para HM000043 - TIENDA005
# ✅ Predicción generada para HM000043 - TIENDA006
# ✅ Predicción generada para HM000043 - TIENDA006
# ✅ Predicción generada para HM000043 - TIENDA007
# ✅ Predicción generada para HM000043 - TIENDA007
# ✅ Predicción generada para HM000043 - TIENDA008
# ✅ Predicción generada para HM000043 - TIENDA008
# ✅ Predicción generada para HM000043 - TIENDA009
# ✅ Predicción generada para HM000043 - TIENDA009
# ✅ Predicción generada para HM000043 - TIENDA010
# ✅ Predicción generada para HM000043 - TIENDA010
# ✅ Predicción generada para HM000044 - TIENDA001
# ✅ Predicción generada para HM000044 - TIENDA001
# ✅ Predicción generada para HM000044 - TIENDA002
# ✅ Predicción generada para HM000044 - TIENDA002
# ✅ Predicción generada para HM000044 - TIENDA003
# ✅ Predicción generada para HM000044 - TIENDA003
# ✅ Predicción generada para HM000044 - TIENDA004
# ✅ Predicción generada para HM000044 - TIENDA004
# ✅ Predicción generada para HM000044 - TIENDA005
# ✅ Predicción generada para HM000044 - TIENDA005
# ✅ Predicción generada para HM000044 - TIENDA006
# ✅ Predicción generada para HM000044 - TIENDA006
# ✅ Predicción generada para HM000044 - TIENDA007
# ✅ Predicción generada para HM000044 - TIENDA007
# ✅ Predicción generada para HM000044 - TIENDA008
# ✅ Predicción generada para HM000044 - TIENDA008
# ✅ Predicción generada para HM000044 - TIENDA009
# ✅ Predicción generada para HM000044 - TIENDA009
# ✅ Predicción generada para HM000044 - TIENDA010
# ✅ Predicción generada para HM000044 - TIENDA010
# ✅ Predicción generada para HM000045 - TIENDA001
# ✅ Predicción generada para HM000045 - TIENDA001
# ✅ Predicción generada para HM000045 - TIENDA002
# ✅ Predicción generada para HM000045 - TIENDA002
# ✅ Predicción generada para HM000045 - TIENDA003
# ✅ Predicción generada para HM000045 - TIENDA003
# ✅ Predicción generada para HM000045 - TIENDA004
# ✅ Predicción generada para HM000045 - TIENDA004
# ✅ Predicción generada para HM000045 - TIENDA005
# ✅ Predicción generada para HM000045 - TIENDA005
# ✅ Predicción generada para HM000045 - TIENDA006
# ✅ Predicción generada para HM000045 - TIENDA006
# ✅ Predicción generada para HM000045 - TIENDA007
# ✅ Predicción generada para HM000045 - TIENDA007
# ✅ Predicción generada para HM000045 - TIENDA008
# ✅ Predicción generada para HM000045 - TIENDA008
# ✅ Predicción generada para HM000045 - TIENDA009
# ✅ Predicción generada para HM000045 - TIENDA009
# ✅ Predicción generada para HM000045 - TIENDA010
# ✅ Predicción generada para HM000045 - TIENDA010
# ✅ Predicción generada para HM000046 - TIENDA001
# ✅ Predicción generada para HM000046 - TIENDA001
# ✅ Predicción generada para HM000046 - TIENDA002
# ✅ Predicción generada para HM000046 - TIENDA002
# ✅ Predicción generada para HM000046 - TIENDA003
# ✅ Predicción generada para HM000046 - TIENDA003
# ✅ Predicción generada para HM000046 - TIENDA004
# ✅ Predicción generada para HM000046 - TIENDA004
# ✅ Predicción generada para HM000046 - TIENDA005
# ✅ Predicción generada para HM000046 - TIENDA005
# ✅ Predicción generada para HM000046 - TIENDA006
# ✅ Predicción generada para HM000046 - TIENDA006
# ✅ Predicción generada para HM000046 - TIENDA007
# ✅ Predicción generada para HM000046 - TIENDA007
# ✅ Predicción generada para HM000046 - TIENDA008
# ✅ Predicción generada para HM000046 - TIENDA008
# ✅ Predicción generada para HM000046 - TIENDA009
# ✅ Predicción generada para HM000046 - TIENDA009
# ✅ Predicción generada para HM000046 - TIENDA010
# ✅ Predicción generada para HM000046 - TIENDA010
# ✅ Predicción generada para HM000047 - TIENDA001
# ✅ Predicción generada para HM000047 - TIENDA001
# ✅ Predicción generada para HM000047 - TIENDA002
# ✅ Predicción generada para HM000047 - TIENDA002
# ✅ Predicción generada para HM000047 - TIENDA003
# ✅ Predicción generada para HM000047 - TIENDA003
# ✅ Predicción generada para HM000047 - TIENDA004
# ✅ Predicción generada para HM000047 - TIENDA004
# ✅ Predicción generada para HM000047 - TIENDA005
# ✅ Predicción generada para HM000047 - TIENDA005
# ✅ Predicción generada para HM000047 - TIENDA006
# ✅ Predicción generada para HM000047 - TIENDA006
# ✅ Predicción generada para HM000047 - TIENDA007
# ✅ Predicción generada para HM000047 - TIENDA007
# ✅ Predicción generada para HM000047 - TIENDA008
# ✅ Predicción generada para HM000047 - TIENDA008
# ✅ Predicción generada para HM000047 - TIENDA009
# ✅ Predicción generada para HM000047 - TIENDA009
# ✅ Predicción generada para HM000047 - TIENDA010
# ✅ Predicción generada para HM000047 - TIENDA010
# ✅ Predicción generada para HM000048 - TIENDA001
# ✅ Predicción generada para HM000048 - TIENDA001
# ✅ Predicción generada para HM000048 - TIENDA002
# ✅ Predicción generada para HM000048 - TIENDA002
# ✅ Predicción generada para HM000048 - TIENDA003
# ✅ Predicción generada para HM000048 - TIENDA003
# ✅ Predicción generada para HM000048 - TIENDA004
# ✅ Predicción generada para HM000048 - TIENDA004
# ✅ Predicción generada para HM000048 - TIENDA005
# ✅ Predicción generada para HM000048 - TIENDA005
# ✅ Predicción generada para HM000048 - TIENDA006
# ✅ Predicción generada para HM000048 - TIENDA006
# ✅ Predicción generada para HM000048 - TIENDA007
# ✅ Predicción generada para HM000048 - TIENDA007
# ✅ Predicción generada para HM000048 - TIENDA008
# ✅ Predicción generada para HM000048 - TIENDA008
# ✅ Predicción generada para HM000048 - TIENDA009
# ✅ Predicción generada para HM000048 - TIENDA009
# ✅ Predicción generada para HM000048 - TIENDA010
# ✅ Predicción generada para HM000048 - TIENDA010
# ✅ Predicción generada para HM000049 - TIENDA001
# ✅ Predicción generada para HM000049 - TIENDA001
# ✅ Predicción generada para HM000049 - TIENDA002
# ✅ Predicción generada para HM000049 - TIENDA002
# ✅ Predicción generada para HM000049 - TIENDA003
# ✅ Predicción generada para HM000049 - TIENDA003
# ✅ Predicción generada para HM000049 - TIENDA004
# ✅ Predicción generada para HM000049 - TIENDA004
# ✅ Predicción generada para HM000049 - TIENDA005
# ✅ Predicción generada para HM000049 - TIENDA005
# ✅ Predicción generada para HM000049 - TIENDA006
# ✅ Predicción generada para HM000049 - TIENDA006
# ✅ Predicción generada para HM000049 - TIENDA007
# ✅ Predicción generada para HM000049 - TIENDA007
# ✅ Predicción generada para HM000049 - TIENDA008
# ✅ Predicción generada para HM000049 - TIENDA008
# ✅ Predicción generada para HM000049 - TIENDA009
# ✅ Predicción generada para HM000049 - TIENDA009
# ✅ Predicción generada para HM000049 - TIENDA010
# ✅ Predicción generada para HM000049 - TIENDA010
# ✅ Predicción generada para HM000050 - TIENDA001
# ✅ Predicción generada para HM000050 - TIENDA001
# ✅ Predicción generada para HM000050 - TIENDA002
# ✅ Predicción generada para HM000050 - TIENDA002
# ✅ Predicción generada para HM000050 - TIENDA003
# ✅ Predicción generada para HM000050 - TIENDA003
# ✅ Predicción generada para HM000050 - TIENDA004
# ✅ Predicción generada para HM000050 - TIENDA004
# ✅ Predicción generada para HM000050 - TIENDA005
# ✅ Predicción generada para HM000050 - TIENDA005
# ✅ Predicción generada para HM000050 - TIENDA006
# ✅ Predicción generada para HM000050 - TIENDA006
# ✅ Predicción generada para HM000050 - TIENDA007
# ✅ Predicción generada para HM000050 - TIENDA007
# ✅ Predicción generada para HM000050 - TIENDA008
# ✅ Predicción generada para HM000050 - TIENDA008
# ✅ Predicción generada para HM000050 - TIENDA009
# ✅ Predicción generada para HM000050 - TIENDA009
# ✅ Predicción generada para HM000050 - TIENDA010
# ✅ Predicción generada para HM000050 - TIENDA010
# ✅ Predicción generada para HM000051 - TIENDA001
# ...
# ✅ Predicción generada para HM000086 - TIENDA003
# ✅ Predicción generada para HM000086 - TIENDA003
# ✅ Predicción generada para HM000086 - TIENDA004
# ✅ Predicción generada para HM000086 - TIENDA004
# ✅ Predicción generada para HM000086 - TIENDA005
# ✅ Predicción generada para HM000086 - TIENDA005
# ✅ Predicción generada para HM000086 - TIENDA006
# ✅ Predicción generada para HM000086 - TIENDA006
# ✅ Predicción generada para HM000086 - TIENDA007
# ✅ Predicción generada para HM000086 - TIENDA007
# ✅ Predicción generada para HM000086 - TIENDA008
# ✅ Predicción generada para HM000086 - TIENDA008
# ✅ Predicción generada para HM000086 - TIENDA009
# ✅ Predicción generada para HM000086 - TIENDA009
# ✅ Predicción generada para HM000086 - TIENDA010
# ✅ Predicción generada para HM000086 - TIENDA010
# ✅ Predicción generada para HM000087 - TIENDA001
# ✅ Predicción generada para HM000087 - TIENDA001
# ✅ Predicción generada para HM000087 - TIENDA002
# ✅ Predicción generada para HM000087 - TIENDA002
# ✅ Predicción generada para HM000087 - TIENDA003
# ✅ Predicción generada para HM000087 - TIENDA003
# ✅ Predicción generada para HM000087 - TIENDA004
# ✅ Predicción generada para HM000087 - TIENDA004
# ✅ Predicción generada para HM000087 - TIENDA005
# ✅ Predicción generada para HM000087 - TIENDA005
# ✅ Predicción generada para HM000087 - TIENDA006
# ✅ Predicción generada para HM000087 - TIENDA006
# ✅ Predicción generada para HM000087 - TIENDA007
# ✅ Predicción generada para HM000087 - TIENDA007
# ✅ Predicción generada para HM000087 - TIENDA008
# ✅ Predicción generada para HM000087 - TIENDA008
# ✅ Predicción generada para HM000087 - TIENDA009
# ✅ Predicción generada para HM000087 - TIENDA009
# ✅ Predicción generada para HM000087 - TIENDA010
# ✅ Predicción generada para HM000087 - TIENDA010
# ✅ Predicción generada para HM000088 - TIENDA001
# ✅ Predicción generada para HM000088 - TIENDA001
# ✅ Predicción generada para HM000088 - TIENDA002
# ✅ Predicción generada para HM000088 - TIENDA002
# ✅ Predicción generada para HM000088 - TIENDA003
# ✅ Predicción generada para HM000088 - TIENDA003
# ✅ Predicción generada para HM000088 - TIENDA004
# ✅ Predicción generada para HM000088 - TIENDA004
# ✅ Predicción generada para HM000088 - TIENDA005
# ✅ Predicción generada para HM000088 - TIENDA005
# ✅ Predicción generada para HM000088 - TIENDA006
# ✅ Predicción generada para HM000088 - TIENDA006
# ✅ Predicción generada para HM000088 - TIENDA007
# ✅ Predicción generada para HM000088 - TIENDA007
# ✅ Predicción generada para HM000088 - TIENDA008
# ✅ Predicción generada para HM000088 - TIENDA008
# ✅ Predicción generada para HM000088 - TIENDA009
# ✅ Predicción generada para HM000088 - TIENDA009
# ✅ Predicción generada para HM000088 - TIENDA010
# ✅ Predicción generada para HM000088 - TIENDA010
# ✅ Predicción generada para HM000089 - TIENDA001
# ✅ Predicción generada para HM000089 - TIENDA001
# ✅ Predicción generada para HM000089 - TIENDA002
# ✅ Predicción generada para HM000089 - TIENDA002
# ✅ Predicción generada para HM000089 - TIENDA003
# ✅ Predicción generada para HM000089 - TIENDA003
# ✅ Predicción generada para HM000089 - TIENDA004
# ✅ Predicción generada para HM000089 - TIENDA004
# ✅ Predicción generada para HM000089 - TIENDA005
# ✅ Predicción generada para HM000089 - TIENDA005
# ✅ Predicción generada para HM000089 - TIENDA006
# ✅ Predicción generada para HM000089 - TIENDA006
# ✅ Predicción generada para HM000089 - TIENDA007
# ✅ Predicción generada para HM000089 - TIENDA007
# ✅ Predicción generada para HM000089 - TIENDA008
# ✅ Predicción generada para HM000089 - TIENDA008
# ✅ Predicción generada para HM000089 - TIENDA009
# ✅ Predicción generada para HM000089 - TIENDA009
# ✅ Predicción generada para HM000089 - TIENDA010
# ✅ Predicción generada para HM000089 - TIENDA010
# ✅ Predicción generada para HM000090 - TIENDA001
# ✅ Predicción generada para HM000090 - TIENDA001
# ✅ Predicción generada para HM000090 - TIENDA002
# ✅ Predicción generada para HM000090 - TIENDA002
# ✅ Predicción generada para HM000090 - TIENDA003
# ✅ Predicción generada para HM000090 - TIENDA003
# ✅ Predicción generada para HM000090 - TIENDA004
# ✅ Predicción generada para HM000090 - TIENDA004
# ✅ Predicción generada para HM000090 - TIENDA005
# ✅ Predicción generada para HM000090 - TIENDA005
# ✅ Predicción generada para HM000090 - TIENDA006
# ✅ Predicción generada para HM000090 - TIENDA006
# ✅ Predicción generada para HM000090 - TIENDA007
# ✅ Predicción generada para HM000090 - TIENDA007
# ✅ Predicción generada para HM000090 - TIENDA008
# ✅ Predicción generada para HM000090 - TIENDA008
# ✅ Predicción generada para HM000090 - TIENDA009
# ✅ Predicción generada para HM000090 - TIENDA009
# ✅ Predicción generada para HM000090 - TIENDA010
# ✅ Predicción generada para HM000090 - TIENDA010
# ✅ Predicción generada para HM000091 - TIENDA001
# ✅ Predicción generada para HM000091 - TIENDA001
# ✅ Predicción generada para HM000091 - TIENDA002
# ✅ Predicción generada para HM000091 - TIENDA002
# ✅ Predicción generada para HM000091 - TIENDA003
# ✅ Predicción generada para HM000091 - TIENDA003
# ✅ Predicción generada para HM000091 - TIENDA004
# ✅ Predicción generada para HM000091 - TIENDA004
# ✅ Predicción generada para HM000091 - TIENDA005
# ✅ Predicción generada para HM000091 - TIENDA005
# ✅ Predicción generada para HM000091 - TIENDA006
# ✅ Predicción generada para HM000091 - TIENDA006
# ✅ Predicción generada para HM000091 - TIENDA007
# ✅ Predicción generada para HM000091 - TIENDA007
# ✅ Predicción generada para HM000091 - TIENDA008
# ✅ Predicción generada para HM000091 - TIENDA008
# ✅ Predicción generada para HM000091 - TIENDA009
# ✅ Predicción generada para HM000091 - TIENDA009
# ✅ Predicción generada para HM000091 - TIENDA010
# ✅ Predicción generada para HM000091 - TIENDA010
# ✅ Predicción generada para HM000092 - TIENDA001
# ✅ Predicción generada para HM000092 - TIENDA001
# ✅ Predicción generada para HM000092 - TIENDA002
# ✅ Predicción generada para HM000092 - TIENDA002
# ✅ Predicción generada para HM000092 - TIENDA003
# ✅ Predicción generada para HM000092 - TIENDA003
# ✅ Predicción generada para HM000092 - TIENDA004
# ✅ Predicción generada para HM000092 - TIENDA004
# ✅ Predicción generada para HM000092 - TIENDA005
# ✅ Predicción generada para HM000092 - TIENDA005
# ✅ Predicción generada para HM000092 - TIENDA006
# ✅ Predicción generada para HM000092 - TIENDA006
# ✅ Predicción generada para HM000092 - TIENDA007
# ✅ Predicción generada para HM000092 - TIENDA007
# ✅ Predicción generada para HM000092 - TIENDA008
# ✅ Predicción generada para HM000092 - TIENDA008
# ✅ Predicción generada para HM000092 - TIENDA009
# ✅ Predicción generada para HM000092 - TIENDA009
# ✅ Predicción generada para HM000092 - TIENDA010
# ✅ Predicción generada para HM000092 - TIENDA010
# ✅ Predicción generada para HM000093 - TIENDA001
# ✅ Predicción generada para HM000093 - TIENDA001
# ✅ Predicción generada para HM000093 - TIENDA002
# ✅ Predicción generada para HM000093 - TIENDA002
# ✅ Predicción generada para HM000093 - TIENDA003
# ✅ Predicción generada para HM000093 - TIENDA003
# ✅ Predicción generada para HM000093 - TIENDA004
# ✅ Predicción generada para HM000093 - TIENDA004
# ✅ Predicción generada para HM000093 - TIENDA005
# ✅ Predicción generada para HM000093 - TIENDA005
# ✅ Predicción generada para HM000093 - TIENDA006
# ✅ Predicción generada para HM000093 - TIENDA006
# ✅ Predicción generada para HM000093 - TIENDA007
# ✅ Predicción generada para HM000093 - TIENDA007
# ✅ Predicción generada para HM000093 - TIENDA008
# ✅ Predicción generada para HM000093 - TIENDA008
# ✅ Predicción generada para HM000093 - TIENDA009
# ✅ Predicción generada para HM000093 - TIENDA009
# ✅ Predicción generada para HM000093 - TIENDA010
# ✅ Predicción generada para HM000093 - TIENDA010
# ✅ Predicción generada para HM000094 - TIENDA001
# ✅ Predicción generada para HM000094 - TIENDA001
# ✅ Predicción generada para HM000094 - TIENDA002
# ✅ Predicción generada para HM000094 - TIENDA002
# ✅ Predicción generada para HM000094 - TIENDA003
# ✅ Predicción generada para HM000094 - TIENDA003
# ✅ Predicción generada para HM000094 - TIENDA004
# ✅ Predicción generada para HM000094 - TIENDA004
# ✅ Predicción generada para HM000094 - TIENDA005
# ✅ Predicción generada para HM000094 - TIENDA005
# ✅ Predicción generada para HM000094 - TIENDA006
# ✅ Predicción generada para HM000094 - TIENDA006
# ✅ Predicción generada para HM000094 - TIENDA007
# ✅ Predicción generada para HM000094 - TIENDA007
# ✅ Predicción generada para HM000094 - TIENDA008
# ✅ Predicción generada para HM000094 - TIENDA008
# ✅ Predicción generada para HM000094 - TIENDA009
# ✅ Predicción generada para HM000094 - TIENDA009
# ✅ Predicción generada para HM000094 - TIENDA010
# ✅ Predicción generada para HM000094 - TIENDA010
# ✅ Predicción generada para HM000095 - TIENDA001
# ✅ Predicción generada para HM000095 - TIENDA001
# ✅ Predicción generada para HM000095 - TIENDA002
# ✅ Predicción generada para HM000095 - TIENDA002
# ✅ Predicción generada para HM000095 - TIENDA003
# ✅ Predicción generada para HM000095 - TIENDA003
# ✅ Predicción generada para HM000095 - TIENDA004
# ✅ Predicción generada para HM000095 - TIENDA004
# ✅ Predicción generada para HM000095 - TIENDA005
# ✅ Predicción generada para HM000095 - TIENDA005
# ✅ Predicción generada para HM000095 - TIENDA006
# ✅ Predicción generada para HM000095 - TIENDA006
# ✅ Predicción generada para HM000095 - TIENDA007
# ✅ Predicción generada para HM000095 - TIENDA007
# ✅ Predicción generada para HM000095 - TIENDA008
# ✅ Predicción generada para HM000095 - TIENDA008
# ✅ Predicción generada para HM000095 - TIENDA009
# ✅ Predicción generada para HM000095 - TIENDA009
# ✅ Predicción generada para HM000095 - TIENDA010
# ✅ Predicción generada para HM000095 - TIENDA010
# ✅ Predicción generada para HM000096 - TIENDA001
# ✅ Predicción generada para HM000096 - TIENDA001
# ✅ Predicción generada para HM000096 - TIENDA002
# ✅ Predicción generada para HM000096 - TIENDA002
# ✅ Predicción generada para HM000096 - TIENDA003
# ✅ Predicción generada para HM000096 - TIENDA003
# ✅ Predicción generada para HM000096 - TIENDA004
# ✅ Predicción generada para HM000096 - TIENDA004
# ✅ Predicción generada para HM000096 - TIENDA005
# ✅ Predicción generada para HM000096 - TIENDA005
# ✅ Predicción generada para HM000096 - TIENDA006
# ✅ Predicción generada para HM000096 - TIENDA006
# ✅ Predicción generada para HM000096 - TIENDA007
# ✅ Predicción generada para HM000096 - TIENDA007
# ✅ Predicción generada para HM000096 - TIENDA008
# ✅ Predicción generada para HM000096 - TIENDA008
# ✅ Predicción generada para HM000096 - TIENDA009
# ✅ Predicción generada para HM000096 - TIENDA009
# ✅ Predicción generada para HM000096 - TIENDA010
# ✅ Predicción generada para HM000096 - TIENDA010
# ✅ Predicción generada para HM000097 - TIENDA001
# ✅ Predicción generada para HM000097 - TIENDA001
# ✅ Predicción generada para HM000097 - TIENDA002
# ✅ Predicción generada para HM000097 - TIENDA002
# ✅ Predicción generada para HM000097 - TIENDA003
# ✅ Predicción generada para HM000097 - TIENDA003
# ✅ Predicción generada para HM000097 - TIENDA004
# ✅ Predicción generada para HM000097 - TIENDA004
# ✅ Predicción generada para HM000097 - TIENDA005
# ✅ Predicción generada para HM000097 - TIENDA005
# ✅ Predicción generada para HM000097 - TIENDA006
# ✅ Predicción generada para HM000097 - TIENDA006
# ✅ Predicción generada para HM000097 - TIENDA007
# ✅ Predicción generada para HM000097 - TIENDA007
# ✅ Predicción generada para HM000097 - TIENDA008
# ✅ Predicción generada para HM000097 - TIENDA008
# ✅ Predicción generada para HM000097 - TIENDA009
# ✅ Predicción generada para HM000097 - TIENDA009
# ✅ Predicción generada para HM000097 - TIENDA010
# ✅ Predicción generada para HM000097 - TIENDA010
# ✅ Predicción generada para HM000098 - TIENDA001
# ✅ Predicción generada para HM000098 - TIENDA001
# ✅ Predicción generada para HM000098 - TIENDA002
# ✅ Predicción generada para HM000098 - TIENDA002
# ✅ Predicción generada para HM000098 - TIENDA003
# ✅ Predicción generada para HM000098 - TIENDA003
# ✅ Predicción generada para HM000098 - TIENDA004
# ✅ Predicción generada para HM000098 - TIENDA004
# ✅ Predicción generada para HM000098 - TIENDA005
# ✅ Predicción generada para HM000098 - TIENDA005
# ✅ Predicción generada para HM000098 - TIENDA006
# ✅ Predicción generada para HM000098 - TIENDA006
# ✅ Predicción generada para HM000098 - TIENDA007
# ✅ Predicción generada para HM000098 - TIENDA007
# ✅ Predicción generada para HM000098 - TIENDA008
# ✅ Predicción generada para HM000098 - TIENDA008
# ✅ Predicción generada para HM000098 - TIENDA009
# ✅ Predicción generada para HM000098 - TIENDA009
# ✅ Predicción generada para HM000098 - TIENDA010
# ✅ Predicción generada para HM000098 - TIENDA010
# ✅ Predicción generada para HM000099 - TIENDA001
# ✅ Predicción generada para HM000099 - TIENDA001
# ✅ Predicción generada para HM000099 - TIENDA002
# ✅ Predicción generada para HM000099 - TIENDA002
# ✅ Predicción generada para HM000099 - TIENDA003
# ✅ Predicción generada para HM000099 - TIENDA003
# ✅ Predicción generada para HM000099 - TIENDA004
# ✅ Predicción generada para HM000099 - TIENDA004
# ✅ Predicción generada para HM000099 - TIENDA005
# ✅ Predicción generada para HM000099 - TIENDA005
# ✅ Predicción generada para HM000099 - TIENDA006
# ✅ Predicción generada para HM000099 - TIENDA006
# ✅ Predicción generada para HM000099 - TIENDA007
# ✅ Predicción generada para HM000099 - TIENDA007
# ✅ Predicción generada para HM000099 - TIENDA008
# ✅ Predicción generada para HM000099 - TIENDA008
# ✅ Predicción generada para HM000099 - TIENDA009
# ✅ Predicción generada para HM000099 - TIENDA009
# ✅ Predicción generada para HM000099 - TIENDA010
# ✅ Predicción generada para HM000099 - TIENDA010
# ✅ Predicción generada para HM000100 - TIENDA001
# ✅ Predicción generada para HM000100 - TIENDA001
# ✅ Predicción generada para HM000100 - TIENDA002
# ✅ Predicción generada para HM000100 - TIENDA002
# ✅ Predicción generada para HM000100 - TIENDA003
# ✅ Predicción generada para HM000100 - TIENDA003
# ✅ Predicción generada para HM000100 - TIENDA004
# ✅ Predicción generada para HM000100 - TIENDA004
# ✅ Predicción generada para HM000100 - TIENDA005
# ✅ Predicción generada para HM000100 - TIENDA005
# ✅ Predicción generada para HM000100 - TIENDA006
# ✅ Predicción generada para HM000100 - TIENDA006
# ✅ Predicción generada para HM000100 - TIENDA007
# ✅ Predicción generada para HM000100 - TIENDA007
# ✅ Predicción generada para HM000100 - TIENDA008
# ✅ Predicción generada para HM000100 - TIENDA008
# ✅ Predicción generada para HM000100 - TIENDA009
# ✅ Predicción generada para HM000100 - TIENDA009
# ✅ Predicción generada para HM000100 - TIENDA010
#
# ✅ Archivo 'resultados_forecast.csv' generado correctamente.
# Filas: 8000
#         sku     tienda fecha_predicha  semana_a_futuro  prediccion_ARIMA
# 0  HM000001  TIENDA001     2024-12-29                1              1.78
# 1  HM000001  TIENDA001     2025-01-05                2              1.75
# 2  HM000001  TIENDA001     2025-01-12                3              1.75
# 3  HM000001  TIENDA001     2025-01-19                4              1.75
# 4  HM000001  TIENDA001     2025-01-26                5              1.75
# 5  HM000001  TIENDA001     2025-02-02                6              1.75
# 6  HM000001  TIENDA001     2025-02-09                7              1.75
# 7  HM000001  TIENDA001     2025-02-16                8              1.75
# 8  HM000001  TIENDA002     2024-12-29                1              1.84
# 9  HM000001  TIENDA002     2025-01-05                2              1.68
# ✅ Predicción generada para HM000100 - TIENDA010
#
# ✅ Archivo 'resultados_forecast.csv' generado correctamente.
# Filas: 8000
#         sku     tienda fecha_predicha  semana_a_futuro  prediccion_ARIMA
# 0  HM000001  TIENDA001     2024-12-29                1              1.78
# 1  HM000001  TIENDA001     2025-01-05                2              1.75
# 2  HM000001  TIENDA001     2025-01-12                3              1.75
# 3  HM000001  TIENDA001     2025-01-19                4              1.75
# 4  HM000001  TIENDA001     2025-01-26                5              1.75
# 5  HM000001  TIENDA001     2025-02-02                6              1.75
# 6  HM000001  TIENDA001     2025-02-09                7              1.75
# 7  HM000001  TIENDA001     2025-02-16                8              1.75
# 8  HM000001  TIENDA002     2024-12-29                1              1.84
# 9  HM000001  TIENDA002     2025-01-05                2              1.68

# %% [markdown]
# ## Validación automática

# %%
# ===============================================================
# 🧩 Validar resultados del forecasting
# ===============================================================
import pandas as pd

try:
    df_forecast = pd.read_csv("resultados_forecast.csv")
    print(f" Total filas: {len(df_forecast)}")
    print(df_forecast.head(10))
except Exception as e:
    print(f" Error al leer el archivo: {e}")

# Diagnóstico adicional (ventas totales)
df_ventas = pd.read_csv("ventas.csv")
resumen = df_ventas.groupby("sku")["cantidad_vendida"].sum().sort_values(ascending=False).head(10)
print("\n Ventas totales (top 10 SKU):\n", resumen)
# Out:
# 📊 Total filas: 8000
#         sku     tienda fecha_predicha  semana_a_futuro  prediccion_ARIMA
# 0  HM000001  TIENDA001     2024-12-29                1              1.78
# 1  HM000001  TIENDA001     2025-01-05                2              1.75
# 2  HM000001  TIENDA001     2025-01-12                3              1.75
# 3  HM000001  TIENDA001     2025-01-19                4              1.75
# 4  HM000001  TIENDA001     2025-01-26                5              1.75
# 5  HM000001  TIENDA001     2025-02-02                6              1.75
# 6  HM000001  TIENDA001     2025-02-09                7              1.75
# 7  HM000001  TIENDA001     2025-02-16                8              1.75
# 8  HM000001  TIENDA002     2024-12-29                1              1.84
# 9  HM000001  TIENDA002     2025-01-05                2              1.68
#
# 🔍 Ventas totales (top 10 SKU):
#  sku
# HM000005    1007.50
# HM000081     994.75
# HM000039     978.90
# HM000067     949.55
# HM000014     945.91
# HM000035     937.41
# HM000034     933.54
# HM000029     931.82
# HM000050     928.53
# HM000001     926.99
# Name: cantidad_vendida, dtype: float64
#
# 🔍 Ventas totales (top 10 SKU):
#  sku
# HM000005    1007.50
# HM000081     994.75
# HM000039     978.90
# HM000067     949.55
# HM000014     945.91
# HM000035     937.41
# HM000034     933.54
# HM000029     931.82
# HM000050     928.53
# HM000001     926.99
# Name: cantidad_vendida, dtype: float64
